# %% [markdown]
# <img src='../images/dsl-logo.png' width="40%" align="left" />
# <img src='../images/hs-aalen-logo.png' width="40%" align="right" />

# %% [markdown]
# # Capital Bikeshare: Anlayse und Prognose der Ausleihvorgänge

# %% [markdown]
# ## 20 - Grobe Säuberung der Daten (Trip und Weather)

# %% [markdown]
# **Hinweis:** Die Notebooks sind so aufgebaut, dass sie zu einer Verarbeitungs-Pipeline gehören und in der Reihenfolge der Nummern (Prefixe) ausgeführt sollten, da spätere Notebooks (die mit einer größeren Anfangsnummer) Daten aus den vorherigen Notebooks verwenden. Nur Notebooks mit ganzen *10*er-Nummern gehören zur eigentlichen Verarbeitungs-Pipeline.

# %%
import datetime
import pandas as pd

# %%
# Konstante Werte für Pfade, Dateinamen und andere Vereinbarungen

# %%
DATA_PATH = '../data/'
RAW_TRIPS_FILE = 'trips_raw.pkl'
CLEAN_TRIPS_FILE = 'trips_clean.pkl'
TRIP_COL_LIST_DUPLICATE_CHECK = ['start_ts', 'end_ts', 'start_station_id', 'end_station_id', 'bike_number']
# Hier Änderung: Member Type mit drin lassen: 
TRIP_COL_LIST_TO_KEEP = ['start_ts', 'end_ts', 'start_station_id', 'end_station_id', 'bike_number', 'Member type']
RAW_WEATHER_FILE = 'weather_raw.pkl'
ALT_WEATHER_FILE = 'weather_alt.pkl'
CLEAN_WEATHER_FILE = 'weather.pkl'
WEATHER_COLS = ['date', 'hour', 'temperature', 'humidity', 'precipitation', 'windspeed','dewpoint', 'pressure']

# %%
# Die (bis auf die Benennung der Merkamle) unveränderten Trip-Daten aus Schritt 1 einlesen
df_trips_raw = pd.read_pickle(DATA_PATH+RAW_TRIPS_FILE)

# %%
# Identische Einträge der relevanten Mermale für Entnahme und Rückgabe eines Fahrrades
# identifieren und entfernen

# %%
def remove_duplicates(df_raw):
    print('Total trips:', df_raw.shape[0])
    # Determining duplicates
    print('Checking for duplicates...')
    duplicates = df_raw.duplicated(subset=TRIP_COL_LIST_DUPLICATE_CHECK, keep='first')
    print('Duplicate trips:', duplicates.sum())
    df_clean = df_raw[~duplicates]
    print('Total trips remaining:', df_clean.shape[0])
    print('Done.')
    return df_clean

# %%
df_trips = remove_duplicates(df_trips_raw)
# Out:
# Total trips: 10277677
# Checking for duplicates...
# Duplicate trips: 0
# Total trips remaining: 10277677
# Done.

# %%
# Überprüfung auf fehlende Werte

# %%
df_trips.isnull().sum()
# Out:
# duration              0
# start_ts              0
# end_ts                0
# start_station_id      0
# start_station_name    0
# end_station_id        0
# end_station_name      0
# bike_number           0
# Member type           0
# dtype: int64

# %%
# Prüfen ob Rückgabe stets vor der nächsten Entnahme liegt und die nächste Entnahme nach der Rückgabe

# %%
# nach Fahrrädern und Zeitstempeln sortieren
df_trips_sorted = df_trips.sort_values(by=['bike_number', 'start_ts', 'end_ts'])
# Berechne DataFrame mit Spalte, bei der die Entnahmezeit um ein Trip verschoben ist (früher)
df_start_shift = df_trips_sorted.groupby(
        by='bike_number', sort=False)[['start_ts']].shift(-1).rename(
            columns={'start_ts': 'next_start_ts'})
# Hänge DataFrames horizontal zusammen - Sortierreihenfolge darf sich nicht verändert haben
df_check = pd.concat([df_trips_sorted, df_start_shift], axis=1)

# %%
df_check.head()
# Out:
#         duration            start_ts              end_ts  start_station_id  \
# 130487     14315 2015-10-15 10:58:35 2015-10-15 14:57:10             31219
# 193289      1501 2016-10-18 10:54:16 2016-10-18 11:19:17             31292
# 207012       727 2016-10-19 12:20:37 2016-10-19 12:32:45             31618
# 241628      1120 2016-10-22 12:07:42 2016-10-22 12:26:22             31249
# 242374      1722 2016-10-22 13:01:26 2016-10-22 13:30:08             31249
#
#                    start_station_name  end_station_id  \
# 130487  10th St & Constitution Ave NW           31634
# 193289  22nd St & Constitution Ave NW           31292
# 207012       4th & East Capitol St NE           31618
# 241628             Jefferson Memorial           31249
# 242374             Jefferson Memorial           31249
#
#                      end_station_name            bike_number Member type  \
# 130487             3rd & Tingey St SE  ?(0x0000000074BEBCE4)      Member
# 193289  22nd St & Constitution Ave NW  ?(0x0000000074BEBCE4)      Member
# 207012       4th & East Capitol St NE  ?(0x0000000074BEBCE4)      Member
# 241628             Jefferson Memorial  ?(0x0000000074BEBCE4)      Member
# 242374             Jefferson Memorial  ?(0x0000000074BEBCE4)      Member
#
#              next_start_ts
# 130487 2016-10-18 10:54:16
# 193289 2016-10-19 12:20:37
# 207012 2016-10-22 12:07:42
# 241628 2016-10-22 13:01:26
# 242374 2016-10-25 10:49:29

# %%
# Es gibt einige Trips, bei denen die Rückgabe nach der nächsten Entnahme liegt ... das geht nicht

# %%
df_check.loc[df_check['end_ts']>=df_check['next_start_ts']]
# Out:
#         duration            start_ts              end_ts  start_station_id  \
# 290539       194 2015-11-01 01:07:52 2015-11-01 01:11:07             31103
# 290703       599 2015-11-01 01:42:03 2015-11-01 01:52:02             31116
# 290517       971 2015-11-01 01:02:08 2015-11-01 01:18:19             31280
# 290711       530 2015-11-01 01:43:21 2015-11-01 01:52:11             31105
# 290730       371 2015-11-01 01:49:02 2015-11-01 01:55:14             31111
# 402149      1260 2016-11-06 01:11:35 2016-11-06 01:32:35             31608
# 290491      1168 2015-11-01 00:56:59 2015-11-01 01:16:28             31221
# 402219       448 2016-11-06 01:43:18 2016-11-06 01:50:47             31268
# 290504       353 2015-11-01 01:00:28 2015-11-01 01:06:21             31509
# 290505      1341 2015-11-01 01:00:29 2015-11-01 01:22:51             31237
# 290595       386 2015-11-01 01:15:51 2015-11-01 01:22:17             31102
# 290567       442 2015-11-01 01:12:30 2015-11-01 01:19:53             31104
# 290606       732 2015-11-01 01:18:29 2015-11-01 01:30:41             31281
# 402154       723 2016-11-06 01:13:47 2016-11-06 01:25:51             31400
# 290649       961 2015-11-01 01:28:08 2015-11-01 01:44:09             31404
# 290534      2604 2015-11-01 01:06:44 2015-11-01 01:50:09             31278
# 290565      1565 2015-11-01 01:11:27 2015-11-01 01:37:32             31114
# 290499      1349 2015-11-01 00:59:13 2015-11-01 01:21:42             31201
# 290545       660 2015-11-01 01:08:35 2015-11-01 01:19:36             31212
# 290589       788 2015-11-01 01:15:24 2015-11-01 01:28:32             31280
# 290688       524 2015-11-01 01:37:31 2015-11-01 01:46:15             31102
# 648030       770 2017-08-20 11:24:18 2017-08-20 11:37:08             31321
#
#                     start_station_name  end_station_id  \
# 290539            16th & Harvard St NW           31107
# 290703  California St & Florida Ave NW           31203
# 290517                  11th & S St NW           31200
# 290711            14th & Harvard St NW           31503
# 290730                  10th & U St NW           31105
# 402149  8th & Eye St SE / Barracks Row           31623
# 290491                  18th & M St NW           31503
# 402219                  12th & U St NW           31102
# 290504        New Jersey Ave & R St NW           31202
# 290505   25th St & Pennsylvania Ave NW           31237
# 290595             11th & Kenyon St NW           31109
# 290567     Adams Mill & Columbia Rd NW           31267
# 290606                   8th & O St NW           31104
# 402154  Georgia & New Hampshire Ave NW           31229
# 290649              9th & Upshur St NW           31114
# 290534                  18th & R St NW           31229
# 290565        18th St & Wyoming Ave NW           31636
# 290499                  15th & P St NW           31606
# 290545                  21st & M St NW           31224
# 290589                  11th & S St NW           31200
# 290688             11th & Kenyon St NW           31268
# 648030   15th St & Constitution Ave NW           31321
#
#                             end_station_name bike_number Member type  \
# 290539               Lamont & Mt Pleasant NW      W00156      Member
# 290703            14th & Rhode Island Ave NW      W00340      Member
# 290517  Massachusetts Ave & Dupont Circle NW      W00397      Member
# 290711                 Florida Ave & R St NW      W00720      Member
# 290730                  14th & Harvard St NW      W00720      Member
# 402149       Columbus Circle / Union Station      W00869      Casual
# 290491                 Florida Ave & R St NW      W01325      Member
# 402219                   11th & Kenyon St NW      W01411      Member
# 290504                        14th & R St NW      W20054      Member
# 290505         25th St & Pennsylvania Ave NW      W20054      Casual
# 290595                         7th & T St NW      W20175      Member
# 290567        17th St & Massachusetts Ave NW      W20476      Member
# 290606           Adams Mill & Columbia Rd NW      W20476      Member
# 402154           New Hampshire Ave & T St NW      W20561      Member
# 290649              18th St & Wyoming Ave NW      W21249      Member
# 290534           New Hampshire Ave & T St NW      W21340      Casual
# 290565    New Jersey Ave & N St NW/Dunbar HS      W21365      Member
# 290499         Potomac & Pennsylvania Ave SE      W21589      Member
# 290545                        19th & L St NW      W21985      Casual
# 290589  Massachusetts Ave & Dupont Circle NW      W22075      Member
# 290688                        12th & U St NW      W22145      Member
# 648030         15th St & Constitution Ave NW      W22442      Member
#
#              next_start_ts
# 290539 2015-11-01 01:09:42
# 290703 2015-11-01 01:49:06
# 290517 2015-11-01 01:03:46
# 290711 2015-11-01 01:49:02
# 290730 2015-11-01 01:52:22
# 402149 2016-11-06 01:24:28
# 290491 2015-11-01 01:05:58
# 402219 2016-11-06 01:44:42
# 290504 2015-11-01 01:00:29
# 290505 2015-11-01 01:14:21
# 290595 2015-11-01 01:16:25
# 290567 2015-11-01 01:18:29
# 290606 2015-11-01 01:21:29
# 402154 2016-11-06 01:16:14
# 290649 2015-11-01 01:29:33
# 290534 2015-11-01 01:12:53
# 290565 2015-11-01 01:27:51
# 290499 2015-11-01 01:02:07
# 290545 2015-11-01 01:09:22
# 290589 2015-11-01 01:18:24
# 290688 2015-11-01 01:38:43
# 648030 2017-08-20 11:37:08

# %%
# Rückgabe-Zeitpunkt kurz vor den nächsten Entnahmezeitpunkt setzen
df_check.loc[df_check['end_ts']>=df_check['next_start_ts'], 'end_ts'] = \
    df_check.loc[df_check['end_ts']>=df_check['next_start_ts']]['next_start_ts'] - pd.Timedelta(1, 'second')

# %%
# Überprüfen
df_check.loc[df_check['end_ts']>=df_check['next_start_ts']]
# Out:
# Empty DataFrame
# Columns: [duration, start_ts, end_ts, start_station_id, start_station_name, end_station_id, end_station_name, bike_number, Member type, next_start_ts]
# Index: []

# %%
# Prüfen, ob Rückgabezeit stets nach Entnahmezeit
df_check[df_check['start_ts'] >= df_check['end_ts']]
# Out:
#         duration            start_ts              end_ts  start_station_id  \
# 290777      1677 2015-11-01 01:59:13 2015-11-01 01:27:11             31401
# 290773       718 2015-11-01 01:58:26 2015-11-01 01:10:25             31245
# 290729      1067 2015-11-01 01:49:02 2015-11-01 01:06:50             31247
# 290743      1911 2015-11-01 01:50:33 2015-11-01 01:22:25             31102
# 402249      1175 2016-11-06 01:55:59 2016-11-06 01:15:34             31102
# 402240       770 2016-11-06 01:51:34 2016-11-06 01:04:24             31254
# 290768       338 2015-11-01 01:56:35 2015-11-01 01:02:13             31116
# 431851       806 2017-11-05 01:53:32 2017-11-05 01:06:59             31266
# 290728      1078 2015-11-01 01:48:59 2015-11-01 01:06:58             31247
# 290742      1032 2015-11-01 01:50:28 2015-11-01 01:07:41             31600
# 431839      2632 2017-11-05 01:47:44 2017-11-05 01:31:37             31275
# 290763       512 2015-11-01 01:54:56 2015-11-01 01:03:28             31110
# 290778       170 2015-11-01 01:59:19 2015-11-01 01:02:09             31611
# 431854       703 2017-11-05 01:54:33 2017-11-05 01:06:17             31401
# 290741       767 2015-11-01 01:50:21 2015-11-01 01:03:09             31228
# 402188      3578 2016-11-06 01:28:02 2016-11-06 01:27:40             31314
# 290725      1912 2015-11-01 01:47:58 2015-11-01 01:19:50             31106
# 290760      1485 2015-11-01 01:54:02 2015-11-01 01:18:47             31121
# 290504       353 2015-11-01 01:00:28 2015-11-01 01:00:28             31509
# 402187      3583 2016-11-06 01:27:57 2016-11-06 01:27:40             31314
# 402237      2685 2016-11-06 01:50:47 2016-11-06 01:35:33             31258
# 402236      2734 2016-11-06 01:49:42 2016-11-06 01:35:16             31258
# 290771      1088 2015-11-01 01:58:13 2015-11-01 01:16:21             31245
# 290747      1563 2015-11-01 01:51:37 2015-11-01 01:17:41             31237
# 431855       254 2017-11-05 01:56:50 2017-11-05 01:01:04             31615
# 290776       187 2015-11-01 01:58:56 2015-11-01 01:02:03             31611
# 402209      2978 2016-11-06 01:36:13 2016-11-06 01:25:51             31277
# 402198      3472 2016-11-06 01:31:51 2016-11-06 01:29:44             31277
# 402255       474 2016-11-06 01:57:47 2016-11-06 01:05:41             31509
# 290735       783 2015-11-01 01:49:33 2015-11-01 01:02:36             31241
# 290770      1389 2015-11-01 01:57:32 2015-11-01 01:20:41             31200
# 431821      1348 2017-11-05 01:39:33 2017-11-05 01:02:02             31015
# 402258       333 2016-11-06 01:59:53 2016-11-06 01:05:26             31114
# 402241      2631 2016-11-06 01:51:34 2016-11-06 01:35:26             31258
# 290746       936 2015-11-01 01:51:23 2015-11-01 01:07:00             31203
# 402254       426 2016-11-06 01:57:42 2016-11-06 01:04:48             31245
# 290744      1848 2015-11-01 01:50:42 2015-11-01 01:21:31             31603
# 290767       355 2015-11-01 01:56:07 2015-11-01 01:02:03             31116
# 402194      3312 2016-11-06 01:30:30 2016-11-06 01:25:42             31277
# 290707      1721 2015-11-01 01:42:38 2015-11-01 01:11:19             31228
# 290765       507 2015-11-01 01:55:19 2015-11-01 01:03:46             31109
# 290769       327 2015-11-01 01:57:26 2015-11-01 01:02:53             31023
# 290749       609 2015-11-01 01:51:47 2015-11-01 01:01:57             31268
# 290758      1397 2015-11-01 01:53:42 2015-11-01 01:16:59             31200
# 402256      1523 2016-11-06 01:58:40 2016-11-06 01:24:03             31101
# 402246       637 2016-11-06 01:53:43 2016-11-06 01:04:20             31231
# 402248       766 2016-11-06 01:55:43 2016-11-06 01:08:30             31223
# 431857      1044 2017-11-05 01:59:09 2017-11-05 01:16:34             31609
# 431856      1081 2017-11-05 01:58:02 2017-11-05 01:16:03             31111
# 402253       533 2016-11-06 01:56:56 2016-11-06 01:05:49             31121
# 402250       525 2016-11-06 01:56:10 2016-11-06 01:04:55             31600
# 402202      3348 2016-11-06 01:33:30 2016-11-06 01:29:18             31277
# 431843      2499 2017-11-05 01:49:58 2017-11-05 01:31:37             31275
# 402193      3316 2016-11-06 01:30:18 2016-11-06 01:25:34             31277
#
#                               start_station_name  end_station_id  \
# 290777                    14th St & Spring Rd NW           31611
# 290773              7th & R St NW / Shaw Library           31603
# 290729                 Jefferson Dr & 14th St SW           31634
# 290743                       11th & Kenyon St NW           31620
# 402249                       11th & Kenyon St NW           31614
# 402240                            15th & K St NW           31202
# 290768            California St & Florida Ave NW           31119
# 431851                            11th & M St NW           31126
# 290728                 Jefferson Dr & 14th St SW           31634
# 290742                             5th & K St NW           31622
# 431839            New Hampshire Ave & 24th St NW           31275
# 290763                  20th St & Florida Ave NW           31109
# 290778                            13th & H St NE           31512
# 431854                    14th St & Spring Rd NW           31101
# 290741                             8th & H St NW           31108
# 402188                        34th & Water St NW           31314
# 290725                  Calvert & Biltmore St NW           31106
# 290760                Calvert St & Woodley Pl NW           31108
# 290504                  New Jersey Ave & R St NW           31202
# 402187                        34th & Water St NW           31314
# 402237                          Lincoln Memorial           31286
# 402236                          Lincoln Memorial           31286
# 290771              7th & R St NW / Shaw Library           31612
# 290747             25th St & Pennsylvania Ave NW           31237
# 431855                             6th & H St NE           31627
# 290776                            13th & H St NE           31512
# 402209                            17th & G St NW           31289
# 402198                            17th & G St NW           31292
# 402255                  New Jersey Ave & R St NW           31600
# 290735                             Thomas Circle           31254
# 290770      Massachusetts Ave & Dupont Circle NW           31226
# 431821  Rosslyn Metro / Wilson Blvd & Ft Myer Dr           31267
# 402258                  18th St & Wyoming Ave NW           31111
# 402241                          Lincoln Memorial           31286
# 290746                14th & Rhode Island Ave NW           31638
# 402254              7th & R St NW / Shaw Library           31505
# 290744                             1st & M St NE           31623
# 290767            California St & Florida Ave NW           31119
# 402194                            17th & G St NW           31289
# 290707                             8th & H St NW           31006
# 290765                             7th & T St NW           31505
# 290769                  Fairfax Dr & Wilson Blvd           31035
# 290749                            12th & U St NW           31203
# 290758      Massachusetts Ave & Dupont Circle NW           31244
# 402256                            14th & V St NW           31249
# 402246   14th & D St NW / Ronald Reagan Building           31108
# 402248         Convention Center / 7th & M St NW           31640
# 431857                     Maine Ave & 7th St SW           31109
# 431856                            10th & U St NW           31108
# 402253                Calvert St & Woodley Pl NW           31107
# 402250                             5th & K St NW           31245
# 402202                            17th & G St NW           31292
# 431843            New Hampshire Ave & 24th St NW           31275
# 402193                            17th & G St NW           31289
#
#                                    end_station_name bike_number Member type  \
# 290777                               13th & H St NE      W00047      Member
# 290773                                1st & M St NE      W00085      Member
# 290729                           3rd & Tingey St SE      W00122      Casual
# 290743                                5th & F St NW      W00141      Casual
# 402249                               11th & H St NE      W00470      Casual
# 402240                               14th & R St NW      W00526      Member
# 290768                         14th & Belmont St NW      W00559      Member
# 431851                          11th & Girard St NW      W00574      Member
# 290728                           3rd & Tingey St SE      W00592      Casual
# 290742                               13th & D St NE      W00754      Member
# 431839               New Hampshire Ave & 24th St NW      W00881      Casual
# 290763                                7th & T St NW      W00963      Member
# 290778                    Neal St & Trinidad Ave NE      W00982      Member
# 431854                               14th & V St NW      W01023      Member
# 290741                                4th & M St SW      W01192      Member
# 402188                           34th & Water St NW      W01299      Casual
# 290725                     Calvert & Biltmore St NW      W01406      Member
# 290760                                4th & M St SW      W01430      Member
# 290504                               14th & R St NW      W20054      Member
# 402187                           34th & Water St NW      W20121      Casual
# 402237                               11th & O St NW      W20132      Casual
# 402236                               11th & O St NW      W20339      Casual
# 290771                       D St & Maryland Ave NE      W20420      Member
# 290747                25th St & Pennsylvania Ave NW      W20452      Casual
# 431855                                3rd & M St NE      W20529      Member
# 290776                    Neal St & Trinidad Ave NE      W20657      Member
# 402209  Henry Bacon Dr & Lincoln Memorial Circle NW      W20680      Casual
# 402198                22nd St & Constitution Ave NW      W20693      Casual
# 402255                                5th & K St NW      W20800      Member
# 290735                               15th & K St NW      W20849      Member
# 290770                   34th St & Wisconsin Ave NW      W20855      Member
# 431821               17th St & Massachusetts Ave NW      W20942      Member
# 402258                               10th & U St NW      W20990      Member
# 402241                               11th & O St NW      W21010      Casual
# 290746                                1st & H St NW      W21018      Member
# 402254                       Eckington Pl & Q St NE      W21027      Member
# 290744              Columbus Circle / Union Station      W21268      Casual
# 290767                         14th & Belmont St NW      W21290      Member
# 402194  Henry Bacon Dr & Lincoln Memorial Circle NW      W21438      Casual
# 290707                       S Joyce & Army Navy Dr      W21453      Member
# 290765                       Eckington Pl & Q St NE      W21771      Member
# 290769                       N Quincy St & Glebe Rd      W21869      Member
# 290749                   14th & Rhode Island Ave NW      W22033      Member
# 290758                                4th & E St SW      W22189      Casual
# 402256                           Jefferson Memorial      W22438      Member
# 402246                                4th & M St SW      W22508      Member
# 402248                       Maryland Ave & E St NE      W22543      Casual
# 431857                                7th & T St NW      W22623      Member
# 431856                                4th & M St SW      W22681      Member
# 402253                      Lamont & Mt Pleasant NW      W22696      Member
# 402250                 7th & R St NW / Shaw Library      W22721      Member
# 402202                22nd St & Constitution Ave NW      W22740      Casual
# 431843               New Hampshire Ave & 24th St NW      W22764      Casual
# 402193  Henry Bacon Dr & Lincoln Memorial Circle NW      W23069      Casual
#
#              next_start_ts
# 290777 2015-11-01 10:56:27
# 290773 2015-11-01 12:48:48
# 290729 2015-11-01 16:26:18
# 290743 2015-11-01 13:18:03
# 402249 2016-11-06 11:39:51
# 402240 2016-11-06 06:57:52
# 290768 2015-11-01 10:30:18
# 431851 2017-11-05 08:01:05
# 290728 2015-11-02 08:58:54
# 290742 2015-11-01 12:27:01
# 431839 2017-11-06 06:55:01
# 290763 2015-11-01 10:16:06
# 290778 2015-11-02 09:21:31
# 431854 2017-11-05 18:25:05
# 290741 2015-11-01 11:12:02
# 402188 2016-11-06 12:27:36
# 290725 2015-11-01 02:31:53
# 290760 2015-11-01 09:39:29
# 290504 2015-11-01 01:00:29
# 402187 2016-11-06 12:32:51
# 402237 2016-11-06 08:04:37
# 402236 2016-11-06 11:01:09
# 290771 2015-11-01 10:23:44
# 290747 2015-11-01 13:27:03
# 431855 2017-11-05 08:33:33
# 290776 2015-11-01 18:31:54
# 402209 2016-11-06 10:53:22
# 402198 2016-11-06 11:49:53
# 402255 2016-11-06 13:35:24
# 290735 2015-11-01 02:33:12
# 290770 2015-11-01 14:45:04
# 431821 2017-11-05 07:05:05
# 402258 2016-11-06 12:13:33
# 402241 2016-11-06 09:42:47
# 290746 2015-11-01 19:06:49
# 402254 2016-11-06 10:02:46
# 290744 2015-11-01 08:10:55
# 290767 2015-11-01 09:51:44
# 402194 2016-11-06 10:37:00
# 290707 2015-11-02 18:13:08
# 290765 2015-11-01 11:03:55
# 290769 2015-11-01 07:30:09
# 290749 2015-11-01 12:08:31
# 290758 2015-11-01 13:24:02
# 402256 2016-11-07 20:47:21
# 402246 2016-11-06 10:49:51
# 402248 2016-11-06 10:37:11
# 431857 2017-11-05 07:48:00
# 431856 2017-11-05 13:38:59
# 402253 2016-11-06 07:19:40
# 402250 2016-11-06 02:03:11
# 402202 2016-11-06 09:26:18
# 431843 2017-11-05 14:46:37
# 402193 2016-11-06 10:35:39

# %%
# Bei einigen Zeilen ist die Rückgabezeit falsch, dies für zu Problemen bei der Zählung der Fahrräder
# Korrektur auf Entnahmezeit plus Delta (1 Sekunde)

# %%
df_check.loc[df_check['start_ts'] >= df_check['end_ts'], 'end_ts'] = \
    df_check.loc[df_check['start_ts'] >= df_check['end_ts']]['start_ts'] + pd.Timedelta(1, 'second')

# %%
# Nochmals prüfen, ob Rückgabezeit stets nach Entnahmezeit
df_check[df_check['start_ts'] >= df_check['end_ts']]
# Out:
# Empty DataFrame
# Columns: [duration, start_ts, end_ts, start_station_id, start_station_name, end_station_id, end_station_name, bike_number, Member type, next_start_ts]
# Index: []

# %%
# Die Simulation der zeitlich sortierten Entnahmen und Rückgaben (Notebook 25) hat gezeigt,
# das es Trips gibt, die parallel zu anderen Trips mit demselben Fahrrad stattfinden.
# Diese müssen entfernt werden:

# %%
df_check[(df_check.bike_number=='W00662') & (df_check.start_ts >= pd.Timestamp(2018, 12,2))][TRIP_COL_LIST_TO_KEEP].head(10)
# Out:
# Empty DataFrame
# Columns: [start_ts, end_ts, start_station_id, end_station_id, bike_number, Member type]
# Index: []

# %%
# einige Trips sind nicht möglich (vgl. Simuation)
trips_to_drop = [219942, 220881]

# %%
df_check.drop(trips_to_drop, inplace=True)

# %%
# Hier Änderung zu seinem Notebook: Mitgliedsstatus wird nicht entfernt, oben in erster Zeile geändert

# %%
# Beschränkung auf die relevanten Attribute (spart Speicherplatz)
df_trips_clean = df_check[TRIP_COL_LIST_TO_KEEP]

# %%
df_trips_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10277653 entries, 130487 to 814482
# Data columns (total 6 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   start_ts          datetime64[ns]
#  1   end_ts            datetime64[ns]
#  2   start_station_id  int64
#  3   end_station_id    int64
#  4   bike_number       object
#  5   Member type       object
# dtypes: datetime64[ns](2), int64(2), object(2)
# memory usage: 548.9+ MB

# %%
# Erzeuge zwei separate Merkmale - Tag (date) als timestamp und Stunde (hour) als int  
# die spätere Verwendung wie z.B. Gruppierung nach Stunden
df_trips_clean.loc[:,'start_date'] = df_trips_clean['start_ts'].apply(lambda dt: pd.Timestamp(dt.date()))
df_trips_clean.loc[:,'start_hour'] = df_trips_clean['start_ts'].apply(lambda dt: dt.time().hour)

df_trips_clean.loc[:,'end_date'] = df_trips_clean['end_ts'].apply(lambda dt: pd.Timestamp(dt.date()))
df_trips_clean.loc[:,'end_hour'] = df_trips_clean['end_ts'].apply(lambda dt: dt.time().hour)
# Out:
# C:\Users\Simon\anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Simon\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df_trips_clean.head()
# Out:
#                   start_ts              end_ts  start_station_id  \
# 130487 2015-10-15 10:58:35 2015-10-15 14:57:10             31219
# 193289 2016-10-18 10:54:16 2016-10-18 11:19:17             31292
# 207012 2016-10-19 12:20:37 2016-10-19 12:32:45             31618
# 241628 2016-10-22 12:07:42 2016-10-22 12:26:22             31249
# 242374 2016-10-22 13:01:26 2016-10-22 13:30:08             31249
#
#         end_station_id            bike_number Member type start_date  \
# 130487           31634  ?(0x0000000074BEBCE4)      Member 2015-10-15
# 193289           31292  ?(0x0000000074BEBCE4)      Member 2016-10-18
# 207012           31618  ?(0x0000000074BEBCE4)      Member 2016-10-19
# 241628           31249  ?(0x0000000074BEBCE4)      Member 2016-10-22
# 242374           31249  ?(0x0000000074BEBCE4)      Member 2016-10-22
#
#         start_hour   end_date  end_hour
# 130487          10 2015-10-15        14
# 193289          10 2016-10-18        11
# 207012          12 2016-10-19        12
# 241628          12 2016-10-22        12
# 242374          13 2016-10-22        13

# %%
# gesäuberte Trip-Date speichern
df_trips_clean.to_pickle(DATA_PATH+CLEAN_TRIPS_FILE)

# %%
df_trips_clean = pd.read_pickle(DATA_PATH+CLEAN_TRIPS_FILE)
